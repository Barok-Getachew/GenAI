# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI


load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response = llm.invoke("How Many moons does jupiter have")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Jupiter has **95 officially recognized moons**.
#
# This number often changes as astronomers discover new, smaller moons orbiting the planet. The most famous are the four largest ones, known as the **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
response= llm.invoke([["system","Answer the questions in shorter form"],["human","How many moons does jupiter have?"]])
print(response.text)
# Out:
# 95

# %%
prompt="write a simple tag line for a coffee shop. Only outline the tag line, nothing less"
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash",temperature=1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# /Users/biruk/Documents/Projects/GenAI/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Your daily cup of comfort.
